# %%
import requests
from bs4 import BeautifulSoup

import random
import re
import pandas as pd
import numpy as np

from datetime import datetime

# %%
wiki_link = 'https://kworb.net/spotify/listeners.html'
#i think monthly listeners is a better metric to see whos trending now

headers = {
            'User-Agent': random.choice([
                'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
                'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7)',
                'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:89.0)',
            ])
        }

html_text = requests.get(wiki_link, headers=headers).text
soup = BeautifulSoup(html_text, 'lxml')

# %%
soup.select('tbody')[0].select('tr')[0].select('td')[0].text
#artist name
# Out:
# 'Bruno Mars'

# %%
soup.select('tbody')[0].select('tr')[0].select('td')[1].text
#monthly listeners
# Out:
# '146,196,248'

# %%
data = soup.select('tbody')[0].select('tr')

# %%
artist = []
monthly_listners = []
for row in data[:500]:
    artist.append(row.select('td')[0].text)
    monthly_listners.append(row.select('td')[1].text)

# %%
monthly_listners
# Out:
# ['146,196,248',
#  '124,386,881',
#  '124,325,960',
#  '111,120,140',
#  '107,895,146',
#  '97,779,735',
#  '91,545,579',
#  '90,751,926',
#  '88,517,529',
#  '86,248,279',
#  '81,746,957',
#  '81,450,181',
#  '80,841,957',
#  '75,767,747',
#  '74,291,276',
#  '73,896,165',
#  '73,479,332',
#  '72,429,105',
#  '68,557,120',
#  '67,029,880',
#  '64,939,480',
#  '63,584,880',
#  '62,838,839',
#  '62,293,829',
#  '61,848,458',
#  '61,492,700',
#  '61,390,969',
#  '60,744,890',
#  '60,658,294',
#  '60,605,876',
#  '60,468,034',
#  '60,141,802',
#  '59,028,638',
#  '57,963,356',
#  '57,253,016',
#  '55,917,695',
#  '54,460,664',
#  '54,079,127',
#  '53,564,307',
#  '53,428,897',
#  '52,888,301',
#  '52,732,575',
#  '52,270,198',
#  '52,158,118',
#  '51,542,135',
#  '50,794,745',
#  '50,629,494',
#  '50,062,677',
#  '49,740,304',
#  '49,723,532',
#  '48,825,632',
#  '48,653,924',
#  '48,447,468',
#  '48,262,958',
#  '47,839,310',
#  '47,778,157',
#  '47,441,176',
#  '47,289,554',
# ...
